# %% [markdown]
# ## Data Exploration

# %%
import numpy as np
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt

# %% [markdown]
# ### Read data

# %%
data = pd.read_json("./new_data_format_Oct20.json")
data = data[data.index == "data"]
data
# Out:
#                              put  \
# data  id:skagerak:13112020161013
#
#                                                   field
# data  [[None, -1.6722530016773631, -1.71674227204408...

# %%
meta = pd.read_json("./new_data_format_Oct20.json")
meta = meta[meta.index == "meta"]
meta = pd.json_normalize( meta['field'])

meta = meta.apply(pd.Series.explode).reset_index(drop=True)
meta
# Out:
#       source  dim.period_cnt  dim.signal_cnt            time.base  \
# 0   skagerak           44640              18  2020-10-01 00:01:00
# 1   skagerak           44640              18  2020-10-01 00:01:00
# 2   skagerak           44640              18  2020-10-01 00:01:00
# 3   skagerak           44640              18  2020-10-01 00:01:00
# 4   skagerak           44640              18  2020-10-01 00:01:00
# 5   skagerak           44640              18  2020-10-01 00:01:00
# 6   skagerak           44640              18  2020-10-01 00:01:00
# 7   skagerak           44640              18  2020-10-01 00:01:00
# 8   skagerak           44640              18  2020-10-01 00:01:00
# 9   skagerak           44640              18  2020-10-01 00:01:00
# 10  skagerak           44640              18  2020-10-01 00:01:00
# 11  skagerak           44640              18  2020-10-01 00:01:00
# 12  skagerak           44640              18  2020-10-01 00:01:00
# 13  skagerak           44640              18  2020-10-01 00:01:00
# 14  skagerak           44640              18  2020-10-01 00:01:00
# 15  skagerak           44640              18  2020-10-01 00:01:00
# 16  skagerak           44640              18  2020-10-01 00:01:00
# 17  skagerak           44640              18  2020-10-01 00:01:00
#
#     time.sample_rate time.unit        signal.sig_id  \
# 0                  1       min             PmP2QAct
# 1                  1       min             PmP2PAct
# 2                  1       min              FedPAct
# 3                  1       min              FedQAct
# 4                  1       min        elspec_PmEAct
# 5                  1       min       PmP2EImportAct
# 6                  1       min        acuvim_PmEAct
# 7                  1       min            Met_WdSpd
# 8                  1       min             Met_Temp
# 9                  1       min      Met_IrrGloHoztl
# 10                 1       min           Met_IrrPOA
# 11                 1       min          Met_ModTemo
# 12                 1       min           SysBatIAct
# 13                 1       min           SysBatEAct
# 14                 1       min      SysBatSocTotAct
# 15                 1       min           SysBatVAct
# 16                 1       min     SysBatChargingSt
# 17                 1       min  SysBatDischargingSt
#
#                                    signal.tag_address  \
# 0   MicroSCADA OPC DA.Skagerak_Microgrid.APL.1.P.N...
# 1   MicroSCADA OPC DA.Skagerak_Microgrid.APL.1.P.N...
# 2   MicroSCADA OPC DA.Skagerak_Microgrid.APL.1.P.P...
# 3   MicroSCADA OPC DA.Skagerak_Microgrid.APL.1.P.P...
# 4   MicroSCADA OPC DA.Skagerak_Microgrid.APL.1.P.N...
# 5   MicroSCADA OPC DA.Skagerak_Microgrid.APL.1.P.N...
# 6   MicroSCADA OPC DA.Skagerak_Microgrid.APL.1.P.P...
# 7   MicroSCADA OPC DA.Skagerak_Microgrid.APL.1.P.P...
# 8   MicroSCADA OPC DA.Skagerak_Microgrid.APL.1.P.P...
# 9   MicroSCADA OPC DA.Skagerak_Microgrid.APL.1.P.P...
# 10  MicroSCADA OPC DA.Skagerak_Microgrid.APL.1.P.P...
# 11  MicroSCADA OPC DA.Skagerak_Microgrid.APL.1.P.P...
# 12  MicroSCADA OPC DA.Skagerak_Microgrid.APL.1.P.B...
# 13  MicroSCADA OPC DA.Skagerak_Microgrid.APL.1.P.B...
# 14  MicroSCADA OPC DA.Skagerak_Microgrid.APL.1.P.B...
# 15  MicroSCADA OPC DA.Skagerak_Microgrid.APL.1.P.B...
# 16  MicroSCADA OPC DA.Skagerak_Microgrid.APL.1.P.B...
# 17  MicroSCADA OPC DA.Skagerak_Microgrid.APL.1.P.B...
#
#                              signal.description signal.unit
# 0            P2 load reactive power measurement        kVAr
# 1              P2 load active power measurement          kW
# 2         P1 + P2 load active power measurement          kW
# 3       P1 + P2 load reactive power measurement        kVAr
# 4     NS4979 active energy export instant value          kW
# 5        P2 load active energy imported counter          kW
# 6   PV active energy export instant value total          kW
# 7                                    Wind speed         m/s
# 8                               Air temperature           C
# 9                  Global horizontal irradiance       W/m^2
# 10                    Plane of array irradiance       W/m^2
# 11                           Module temperature           C
# 12                       Battery actual current           A
# 13                        Battery actual energy         kWh
# 14               Battery SOC total (calculated)           %
# 15                       Battery actual voltage           V
# 16                             Battery charging       (0/1)
# 17                          Battery discharging       (0/1)

# %% [markdown]
# Above we can see the metadata of the signals.

# %%
df = pd.DataFrame()

signals = data.explode('field')['field']
for i, sig_id in enumerate(meta["signal.sig_id"]):
    df[sig_id] = signals[i]

pv = df.filter(['acuvim_PmEAct', 'Met_WdSpd', 'Met_Temp', 'Met_IrrGloHoztl', 'Met_IrrPOA', 'Met_ModTemo'])
pv.head()
# Out:
#    acuvim_PmEAct  Met_WdSpd  Met_Temp  Met_IrrGloHoztl  Met_IrrPOA  \
# 0            NaN        NaN       NaN              NaN         NaN
# 1            NaN        5.0       NaN              NaN         NaN
# 2            NaN        NaN       NaN              NaN         NaN
# 3            NaN        4.0       NaN              NaN         NaN
# 4            NaN        3.0       NaN              NaN         NaN
#
#    Met_ModTemo
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
pv.isna().sum()
# Out:
# acuvim_PmEAct      27606
# Met_WdSpd          29393
# Met_Temp           34681
# Met_IrrGloHoztl    33430
# Met_IrrPOA         33602
# Met_ModTemo        44628
# dtype: int64

# %% [markdown]
# ### Clean PV-Data
#
# Now that we got the PV-data, we have to examine what is there. The meta-data suggests that every signal is sampled every minute, but as there are a lot of NaN-values its hard to believe. First of all, we can observe that Modular Temperature contains almost no values, so this can be removed.
# In addtion, it looks like zero-values (e.g irridation at night) are set to nan. Therefore we fill missing values by interpolation.

# %%
pv = pv.drop(['Met_ModTemo'], axis = 1)

# %%
pv = pv.fillna(0, limit = 1)
pv = pv.interpolate()

# %%
plt.figure(figsize= (20, 10))
plt.plot(range(44640), pv.Met_IrrGloHoztl)
plt.plot(range(44640), pv.acuvim_PmEAct)
plt.plot(range(44640), pv.Met_Temp*10)
plt.show()

# %%
corr = pv.corr()
sn.heatmap(corr, vmin = -1, vmax = 1, center = 0)
plt.show()

# %%
corr
# Out:
#                  acuvim_PmEAct  Met_WdSpd  Met_Temp  Met_IrrGloHoztl  \
# acuvim_PmEAct         1.000000   0.043095  0.267232         0.989859
# Met_WdSpd             0.043095   1.000000  0.403404         0.047137
# Met_Temp              0.267232   0.403404  1.000000         0.271129
# Met_IrrGloHoztl       0.989859   0.047137  0.271129         1.000000
# Met_IrrPOA            0.971814   0.039621  0.233571         0.972649
#
#                  Met_IrrPOA
# acuvim_PmEAct      0.971814
# Met_WdSpd          0.039621
# Met_Temp           0.233571
# Met_IrrGloHoztl    0.972649
# Met_IrrPOA         1.000000

# %% [markdown]
# From the corrolation we can see that production is mainly driven by Global horizontal irradiance. It can also be seen that Plane of array irradiance affects it, but as correlation between this and Global is high, it does not provide more information. Production is also somewhat affected by temperature, which can be included in a model.

# %%
from datetime import datetime, timedelta
start = datetime(2020, 10, 1, 1)
dates = pd.date_range(start,  start + timedelta(minutes = 44639), periods=44640)
pv['date'] = dates

# %%
pv_reduced = pv.filter(['date','acuvim_PmEAct', 'Met_Temp', 'Met_IrrGloHoztl'])

# %%
pv_reduced.to_csv('./pv_red.csv', index=False)

# %% [markdown]
# ## Observations from CAMS

# %%
df_obs = pd.read_csv("./uv_observations.csv", delimiter = ";", parse_dates = ['# Observation period'], infer_datetime_format= False)
df_obs.rename(columns = {'# Observation period': 'date'}, inplace = True)
df_obs.drop(df.tail(1440).index, inplace = True)

# %%
plt.figure(figsize = (20, 10))
plt.plot(range(df_obs.shape[0]), df_obs.GHI*60)
plt.plot(range(df_obs.shape[0]), pv.Met_IrrGloHoztl)
plt.title("Comparison of CAMS data vs. measured at Skagerak")
plt.legend(["Observed Data", "Measured Data"])
plt.show()

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(df_obs.GHI*60, pv.Met_IrrGloHoztl)
# Out:
# 1021.9821429192466

# %%
y_true = df_obs.GHI.to_numpy()*60
y_pred = pv.Met_IrrGloHoztl.to_numpy()
y_true[y_true == 0] = 0.00000001
np.mean(np.abs((y_true - y_pred) / y_true)) * 100
# Out:
# 13783570344.497776

# %%
plt.figure(figsize = (20, 10))
plt.plot(range(df_obs.shape[0]), y_true - y_pred)
plt.show()

# %% [markdown]
# ## Solcast

# %%
import solcast
url = "https://api.solcast.com.au/world_radiation/estimated_actuals?latitude=59.211437&longitude=9.589975&hours=168"
api_key = "_pcnbq8DNwn4gVIGjrgeaBOMoNqCbnJ5"

# %%
forecast = solcast.get_radiation_forecasts(59.211437,9.589975, api_key)

# %%
df_sol = pd.read_csv("./solcast_data.csv", parse_dates=['PeriodStart', "PeriodEnd"])
#df_sol = df_sol[(df_sol['PeriodEnd'] > "2020-10-01") & (df_sol['PeriodStart'] < "2020-11-01")].reset_index()
df_sol.rename(columns = {"PeriodStart": 'date'}, inplace = True)
df_sol['date'] = df_sol['date'].dt.tz_localize(None)
df_sol
# Out:
#                       PeriodEnd                date Period  AirTemp  \
# 0     2020-08-31 00:10:00+00:00 2020-08-31 00:05:00   PT5M      7.7
# 1     2020-08-31 00:15:00+00:00 2020-08-31 00:10:00   PT5M      7.7
# 2     2020-08-31 00:20:00+00:00 2020-08-31 00:15:00   PT5M      7.7
# 3     2020-08-31 00:25:00+00:00 2020-08-31 00:20:00   PT5M      7.6
# 4     2020-08-31 00:30:00+00:00 2020-08-31 00:25:00   PT5M      7.6
# ...                         ...                 ...    ...      ...
# 20715 2020-11-10 22:25:00+00:00 2020-11-10 22:20:00   PT5M      6.7
# 20716 2020-11-10 22:30:00+00:00 2020-11-10 22:25:00   PT5M      6.7
# 20717 2020-11-10 22:35:00+00:00 2020-11-10 22:30:00   PT5M      6.7
# 20718 2020-11-10 22:40:00+00:00 2020-11-10 22:35:00   PT5M      6.7
# 20719 2020-11-10 22:45:00+00:00 2020-11-10 22:40:00   PT5M      6.7
#
#        CloudOpacity  Dhi  Dni  Ebh  Ghi
# 0              55.6    0    0    0    0
# 1              33.6    0    0    0    0
# 2              15.5    0    0    0    0
# 3               9.5    0    0    0    0
# 4               4.2    0    0    0    0
# ...             ...  ...  ...  ...  ...
# 20715          58.8    0    0    0    0
# 20716          58.5    0    0    0    0
# 20717          54.9    0    0    0    0
# 20718          41.2    0    0    0    0
# 20719          26.9    0    0    0    0
#
# [20720 rows x 9 columns]

# %%
sol = pv.merge(df_sol, how='left').dropna()
sol.head()
# Out:
#     acuvim_PmEAct  Met_WdSpd   Met_Temp  Met_IrrGloHoztl  Met_IrrPOA  \
# 0        0.000000       0.00   0.000000         0.000000    0.000000
# 5        0.018546       3.25   9.428571         0.089820    0.090361
# 10       0.037092       3.00  13.221428         0.179641    0.180723
# 15       0.055638       2.60  13.257143         0.269461    0.271084
# 20       0.074184       4.00  13.292857         0.359281    0.361446
#
#                   date                 PeriodEnd Period  AirTemp  \
# 0  2020-10-01 01:00:00 2020-10-01 01:05:00+00:00   PT5M     12.2
# 5  2020-10-01 01:05:00 2020-10-01 01:10:00+00:00   PT5M     12.1
# 10 2020-10-01 01:10:00 2020-10-01 01:15:00+00:00   PT5M     12.1
# 15 2020-10-01 01:15:00 2020-10-01 01:20:00+00:00   PT5M     12.1
# 20 2020-10-01 01:20:00 2020-10-01 01:25:00+00:00   PT5M     12.1
#
#     CloudOpacity  Dhi  Dni  Ebh  Ghi
# 0           58.6  0.0  0.0  0.0  0.0
# 5           56.3  0.0  0.0  0.0  0.0
# 10          53.8  0.0  0.0  0.0  0.0
# 15          51.4  0.0  0.0  0.0  0.0
# 20          49.2  0.0  0.0  0.0  0.0

# %%
plt.figure(figsize = (20, 10))

plt.plot(range(sol.shape[0]), sol.Met_IrrGloHoztl)
plt.plot(range(sol.shape[0]), sol.Ghi)
plt.title("Solcast Predicted Irridation vs. measured at Skagerak")
plt.legend(["Measured", "Predicted"])
plt.show()

# %%
mean_squared_error(sol.Met_IrrGloHoztl, sol.Ghi)
# Out:
# 2211.6383710847117

# %%
sol.corr()
# Out:
#                  acuvim_PmEAct  Met_WdSpd  Met_Temp  Met_IrrGloHoztl  \
# acuvim_PmEAct         1.000000   0.035158  0.267517         0.988891
# Met_WdSpd             0.035158   1.000000  0.397981         0.038233
# Met_Temp              0.267517   0.397981  1.000000         0.271135
# Met_IrrGloHoztl       0.988891   0.038233  0.271135         1.000000
# Met_IrrPOA            0.970453   0.033234  0.233121         0.972890
# AirTemp               0.341065   0.327729  0.845558         0.338541
# CloudOpacity         -0.270665   0.125167  0.223104        -0.280785
# Dhi                   0.739065   0.027734  0.155219         0.731368
# Dni                   0.565624   0.011567  0.040321         0.572773
# Ebh                   0.611880   0.013671  0.058275         0.606946
# Ghi                   0.833362   0.025831  0.133624         0.825536
#
#                  Met_IrrPOA   AirTemp  CloudOpacity       Dhi       Dni  \
# acuvim_PmEAct      0.970453  0.341065     -0.270665  0.739065  0.565624
# Met_WdSpd          0.033234  0.327729      0.125167  0.027734  0.011567
# Met_Temp           0.233121  0.845558      0.223104  0.155219  0.040321
# Met_IrrGloHoztl    0.972890  0.338541     -0.280785  0.731368  0.572773
# Met_IrrPOA         1.000000  0.342688     -0.258479  0.781642  0.578470
# AirTemp            0.342688  1.000000      0.302865  0.345488  0.109635
# CloudOpacity      -0.258479  0.302865      1.000000 -0.153751 -0.453270
# Dhi                0.781642  0.345488     -0.153751  1.000000  0.286301
# Dni                0.578470  0.109635     -0.453270  0.286301  1.000000
# Ebh                0.636197  0.146078     -0.406361  0.322811  0.948845
# Ghi                0.874921  0.307048     -0.337976  0.829699  0.742643
#
#                       Ebh       Ghi
# acuvim_PmEAct    0.611880  0.833362
# Met_WdSpd        0.013671  0.025831
# Met_Temp         0.058275  0.133624
# Met_IrrGloHoztl  0.606946  0.825536
# Met_IrrPOA       0.636197  0.874921
# AirTemp          0.146078  0.307048
# CloudOpacity    -0.406361 -0.337976
# Dhi              0.322811  0.829699
# Dni              0.948845  0.742643
# Ebh              1.000000  0.796156
# Ghi              0.796156  1.000000

# %%
sol.to_csv('./pv_extended.csv')
